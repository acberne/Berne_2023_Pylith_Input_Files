# %%
# load packages
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# modify global setting
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.family'] = 'Verdana'

from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator


font = {'family' : 'sans-serif',
        'weight' : 'bold',
        'size'   : 16}

mpl.rc('font', **font)

fontname= 'Verdana'

from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
import pandas as pd

from matplotlib import cm, colors
from mpl_toolkits.mplot3d import Axes3D
from scipy.special import sph_harm
import math



from scipy.interpolate import make_interp_spline

subt=1
fontsize_label=22



Vtkfile=pd.read_csv("h2_vs_MST_base.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_base=df1.to_numpy()




Vtkfile=pd.read_csv("h2_vs_MST_SM.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM=df1.to_numpy()


Vtkfile=pd.read_csv("h2_vs_MST_SM_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM_faulted=df1.to_numpy()



Vtkfile=pd.read_csv("h2_vs_MST_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_faulted=df1.to_numpy()



Vtkfile=pd.read_csv("h22_vs_MST_WZ.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_WZ=df1.to_numpy()

print(h2_vs_MST_WZ)
y1=(h2_vs_MST_base)
y2 = (h2_vs_MST_SM)
y3=h2_vs_MST_SM_faulted
y4=h2_vs_MST_faulted
y5=h2_vs_MST_WZ
##


Vtkfile=pd.read_csv("h20_vs_MST_base.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_base=df1.to_numpy()




Vtkfile=pd.read_csv("h20_vs_MST_SM.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM=df1.to_numpy()


Vtkfile=pd.read_csv("h20_vs_MST_SM_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM_faulted=df1.to_numpy()



Vtkfile=pd.read_csv("h20_vs_MST_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_faulted=df1.to_numpy()

##



Vtkfile=pd.read_csv("h22_vs_MST_WZ.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_WZ=df1.to_numpy()

##





y10=(h2_vs_MST_base)
y20 = (h2_vs_MST_SM)
y30=h2_vs_MST_SM_faulted
y40=h2_vs_MST_faulted
y50=h2_vs_MST_WZ

y1s=y1/y10
y2s=y2/y20
y3s=y3/y30
y4s=y4/y40
y5s=y5/y50

for i in range(len(y1s)):
    y1s[i]=1


R=1



x=np.array([15/R, 17.5/R, 20/R, 22.5/R, 25/R,27.5/R, 30/R])


X_Y_Spline= make_interp_spline(x,y1)
X_ = np.linspace(x.min(),x.max(),500)
Y_=X_Y_Spline(X_)

fig, ax= plt.subplots(nrows=3, ncols=2,figsize=(20,20))

##First subplot


ax[0,0].yaxis.set_label_coords(-0.20,0.5)


#ax[0,0].plot(X_,Y_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



X_Y_Spline2= make_interp_spline(x,y2)
X_ = np.linspace(x.min(),x.max(),500)
Y2_=X_Y_Spline2(X_)

Y2_spec=Y2_

#ax[0,0].plot(X_,Y2_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



x1=np.array([15/R, 17.5/R, 20/R,22.5/R, 25/R,27.5/R, 30/R])



X_Y_Spline3= make_interp_spline(x1,y3)
X_ = np.linspace(x.min(),x.max(),500)
Y3_=X_Y_Spline3(X_)

Y3_spec=Y3_

#ax[0,0].plot(X_,Y3_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)


X_Y_Spline4= make_interp_spline(x1,y4)
X_ = np.linspace(x.min(),x.max(),500)
Y4_=X_Y_Spline4(X_)

Y4_spec=Y4_

#ax[0,0].plot(X_,Y4_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)





X_Y_Spline5= make_interp_spline(x1,y5)
X_ = np.linspace(x.min(),x.max(),500)
Y5_=X_Y_Spline5(X_)

Y5_spec=Y5_

ax[0,0].plot(X_,Y5_,   
color='orange' ,   # marker edge width
linestyle='-',            # line style will be dash line
linewidth=2)





#ax[0].legend(['Base','LTV','Faults + LTV','Faults'])

ax[0,0].set_ylim(3.5e-2,11.5e-2)
ax[0,0].set_xlim(15/R,30/R)
#plt.yticks(np.arange(min(Y_), max(Y_), 0.002))
ax[0,0].ticklabel_format(axis="y", style="sci",scilimits=(0,0))

#ax[0].set_xlabel('Mean Elastic Outer Shell Thickness (km)',fontsize=14.0, fontweight='bold')
ax[0,0].set_ylabel('$h_{22}$',fontsize=fontsize_label, fontweight='bold',rotation=90)
ax[0,0].yaxis.set_label_coords(-0.12,0.45)





MST_vals=[0/R,15/R,17.5/R,20/R,22.5/R,25/R,27.5/R,30/R]
no_vals=6
MST_err_LTV=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y2_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_LTV[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))
  
    if MST_err_LTV[j]<0:
        MST_err_LTV[j]=0
    
            
MST_err_B=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y3_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_B[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))

    if MST_err_B[j]<0:
        MST_err_B[j]=0
    
MST_err_F=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y4_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_F[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))
    if MST_err_F[j]<0:
        MST_err_F[j]=0
    
    
MST_err_Fs=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y5_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_Fs[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))
    if MST_err_Fs[j]<0:
        MST_err_Fs[j]=0
        
MST_err_F_h2=MST_err_F[1:no_vals-1]*subt
MST_err_B_h2=MST_err_B[1:no_vals-1]*subt
MST_err_LTV_h2=MST_err_LTV[1:no_vals-1]*subt
MST_err_Fs_h2=MST_err_Fs[1:no_vals-1]*subt





#####


x=np.array([15/R, 17.5/R, 20/R, 22.5/R, 25/R,27.5/R, 30/R])


X_Y_Spline= make_interp_spline(x,y1s)
X_ = np.linspace(x.min(),x.max(),500)
Y_=X_Y_Spline(X_)



ax[2,0].yaxis.set_label_coords(-0.20,0.5)


#ax[2,0].plot(X_,Y_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



X_Y_Spline2= make_interp_spline(x,y2s)
X_ = np.linspace(x.min(),x.max(),500)
Y2_=X_Y_Spline2(X_)

Y2_spec=Y2_

#ax[2,0].plot(X_,Y2_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



x1=np.array([15/R, 17.5/R, 20/R,22.5/R, 25/R,27.5/R, 30/R])



X_Y_Spline3= make_interp_spline(x1,y3s)
X_ = np.linspace(x.min(),x.max(),500)
Y3_=X_Y_Spline3(X_)

Y3_spec=Y3_

for i in range(len(Y3_)):
    if Y3_[i]<1.0041:
        Y3_[i]=1.004


#ax[2,0].plot(X_,Y3_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)


X_Y_Spline4= make_interp_spline(x1,y4s)
X_ = np.linspace(x.min(),x.max(),500)
Y4_=X_Y_Spline4(X_)

Y4_spec=Y4_

#ax[2,0].plot(X_,Y4_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



X_Y_Spline5= make_interp_spline(x1,y5s)
X_ = np.linspace(x.min(),x.max(),500)
Y5_=X_Y_Spline5(X_)

Y5_spec=Y5_

ax[2,0].plot(X_,Y5_,   
color='orange' ,   # marker edge width
linestyle='-',            # line style will be dash line
linewidth=2)



#ax[2,0].set_ylim(0.8e-2,2.9e-2)
ax[2,0].set_xlim(15/R,30/R)
#plt.yticks(np.arange(min(Y_), max(Y_), 0.002))
ax[2,0].ticklabel_format(axis="y", style="sci",scilimits=(0,0))

#ax[0].set_xlabel('Mean Elastic Outer Shell Thickness (km)',fontsize=14.0, fontweight='bold')
ax[2,0].set_ylabel('$h_{22}$/$h_{20}$',fontsize=fontsize_label, fontweight='bold',rotation=90)
ax[2,0].yaxis.set_label_coords(-0.12,0.45)






#ax[1].legend(['Base','LTV','Faults + LTV','Faults'])


#Y5_=Y2_+Y4_


#ax[1,0].plot(X_,Y5_,   
#color='white' ,   # marker edge width
#linestyle='--',            # line style will be dash line
#linewidth=2)



#ax[1,0].ticklabel_format(axis="y", style="sci",scilimits=(0,0))


ax[0,0].yaxis.set_label_coords(-0.14,0.45)

#ax.xaxis.set_minor_locator(MultipleLocator(0.1))




##Third subplot




Vtkfile=pd.read_csv("k2_vs_MST_base.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_base=df1.to_numpy()




Vtkfile=pd.read_csv("k2_vs_MST_SM.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM=df1.to_numpy()


Vtkfile=pd.read_csv("k2_vs_MST_SM_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM_faulted=df1.to_numpy()



Vtkfile=pd.read_csv("k2_vs_MST_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_faulted=df1.to_numpy()

Vtkfile=pd.read_csv("k22_vs_MST_WZ.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_WZ=df1.to_numpy()



y1=(h2_vs_MST_base)
y2 = (h2_vs_MST_SM)
y3=h2_vs_MST_SM_faulted
y4=h2_vs_MST_faulted
y5=h2_vs_MST_WZ

###

Vtkfile=pd.read_csv("k20_vs_MST_base.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_base=df1.to_numpy()




Vtkfile=pd.read_csv("k20_vs_MST_SM.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM=df1.to_numpy()


Vtkfile=pd.read_csv("k20_vs_MST_SM_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_SM_faulted=df1.to_numpy()



Vtkfile=pd.read_csv("k20_vs_MST_faulted.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_faulted=df1.to_numpy()

##




Vtkfile=pd.read_csv("k20_vs_MST_WZ.txt", 
                          sep=" ",
                          index_col=False)
df1=Vtkfile
h2_vs_MST_WZ=df1.to_numpy()

##


y10=(h2_vs_MST_base)
y20 = (h2_vs_MST_SM)
y30=h2_vs_MST_SM_faulted
y40=h2_vs_MST_faulted
y50=h2_vs_MST_WZ


y1s=y1/y10
y2s=y2/y20
y3s=y3/y30
y4s=y4/y40
y5s=y5/y50

for i in range(len(y1s)):
    y1s[i]=1


x=np.array([15/R, 17.5/R, 20/R, 22.5/R, 25/R,27.5/R, 30/R])


X_Y_Spline= make_interp_spline(x,y1)
X_ = np.linspace(x.min(),x.max(),500)
Y_=X_Y_Spline(X_)



ax[0,1].yaxis.set_label_coords(-0.20,0.5)


#ax[0,1].plot(X_,Y_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



X_Y_Spline2= make_interp_spline(x,y2)
X_ = np.linspace(x.min(),x.max(),500)
Y2_=X_Y_Spline2(X_)

Y2_spec=Y2_

#ax[0,1].plot(X_,Y2_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



x1=np.array([15/R, 17.5/R, 20/R,22.5/R, 25/R,27.5/R, 30/R])



X_Y_Spline3= make_interp_spline(x1,y3)
X_ = np.linspace(x.min(),x.max(),500)
Y3_=X_Y_Spline3(X_)

Y3_spec=Y3_



#ax[0,1].plot(X_,Y3_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)


X_Y_Spline4= make_interp_spline(x1,y4)
X_ = np.linspace(x.min(),x.max(),500)
Y4_=X_Y_Spline4(X_)

Y4_spec=Y4_

ax[0,1].plot(X_,Y4_,   
color='white' ,   # marker edge width
linestyle='-',            # line style will be dash line
linewidth=2)




X_Y_Spline5= make_interp_spline(x1,y5)
X_ = np.linspace(x.min(),x.max(),500)
Y5_=X_Y_Spline5(X_)

Y5_spec=Y5_

ax[0,1].plot(X_,Y5_,   
color='orange' ,   # marker edge width
linestyle='-',            # line style will be dash line
linewidth=2)





ax[0,1].legend(['Base','LTV','Faults + LTV','Faults','Faults + LTV + WZ'])

ax[0,1].set_ylim(0.8e-2,2.9e-2)
ax[0,1].set_xlim(15/R,30/R)
#plt.yticks(np.arange(min(Y_), max(Y_), 0.002))
ax[0,1].ticklabel_format(axis="y", style="sci",scilimits=(0,0))

#ax[0].set_xlabel('Mean Elastic Outer Shell Thickness (km)',fontsize=14.0, fontweight='bold')
ax[0,1].set_ylabel('$k_{22}$',fontsize=fontsize_label, fontweight='bold',rotation=90)
ax[0,1].yaxis.set_label_coords(-0.12,0.45)






MST_vals=[0,15/R,17.5/R,20/R,22.5/R,25/R,27.5/R,30/R]
no_vals=6
MST_err_LTV=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y2_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_LTV[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))
  
    if MST_err_LTV[j]<0:
        MST_err_LTV[j]=0
    
            
MST_err_B=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y3_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_B[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))

    if MST_err_B[j]<0:
        MST_err_B[j]=0
    
MST_err_F=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y4_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_F[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))
    if MST_err_F[j]<0:
        MST_err_F[j]=0

    
MST_err_Fs=np.zeros(no_vals)
for j in range(1,no_vals):
    MST_err_X=X_[np.argmin(np.abs((Y5_spec-Y_[int((j-1)*(Y_.shape[0]/no_vals))])))]
    MST_err_Fs[j]=(100*(MST_err_X-MST_vals[j])/(MST_vals[j]))
    if MST_err_Fs[j]<0:
        MST_err_Fs[j]=0
    
    
MST_err_F_k2=MST_err_F[1:no_vals-1]*subt
MST_err_Fs_k2=MST_err_Fs[1:no_vals-1]*subt
MST_err_B_k2=MST_err_B[1:no_vals-1]*subt
MST_err_LTV_k2=MST_err_LTV[1:no_vals-1]*subt
MST_vals=MST_vals[1:no_vals-1]









#Y5_=Y2_+Y4_


#ax[1,1].plot(X_,Y5_,   
#color='white' ,   # marker edge width
#linestyle='--',            # line style will be dash line
#linewidth=2)




#ax[1].legend(['Base','LTV','Faults + LTV','Faults'])


#ax[1,1].ticklabel_format(axis="y", style="sci",scilimits=(0,0))


ax[0,1].yaxis.set_label_coords(-0.11,0.45)
ax[0,1].yaxis.set_label_coords(-0.11,0.45)
ax[0,1].set_ylim(1.1e-2,3.5e-2)
ax[0,0].set_ylim(3.0e-2,12e-2)










X_Y_Spline2= make_interp_spline(MST_vals,MST_err_F_h2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)

    
MST_err_F_h2=X_Y_Spline2(X_)



X_Y_Spline2= make_interp_spline(MST_vals,MST_err_B_h2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)

MST_err_B_h2=X_Y_Spline2(X_)


X_Y_Spline2= make_interp_spline(MST_vals,MST_err_LTV_h2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)

    
MST_err_LTV_h2=X_Y_Spline2(X_)


X_Y_Spline2= make_interp_spline(MST_vals,MST_err_F_k2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)

    
    
MST_err_F_k2=X_Y_Spline2(X_)



X_Y_Spline2= make_interp_spline(MST_vals,MST_err_B_k2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)

    
MST_err_B_k2=X_Y_Spline2(X_)


X_Y_Spline2= make_interp_spline(MST_vals,MST_err_LTV_k2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)
MST_err_LTV_k2=X_Y_Spline2(X_)

X_Y_Spline2= make_interp_spline(MST_vals,MST_err_Fs_h2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)

MST_err_Fs_h2=X_Y_Spline2(X_)


X_Y_Spline2= make_interp_spline(MST_vals,MST_err_Fs_k2,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)

MST_err_Fs_k2=X_Y_Spline2(X_)




ax[1,1].plot(X_,MST_err_Fs_k2,   
color='orange' ,   # marker edge width
linestyle='-',            # line style will be dash line
linewidth=2)


#ax[1,1].plot(X_,MST_err_F_k2,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)




#ax[1,1].plot(X_,MST_err_B_k2,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)

#ax[1,1].plot(X_,MST_err_LTV_k2,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)







#ax[1,0].plot(X_,MST_err_F_h2,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)


#ax[1,0].plot(X_,MST_err_B_h2,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)

#ax[1,0].plot(X_,MST_err_LTV_h2,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)
ax[1,0].plot(X_,MST_err_Fs_h2,   
color='orange' ,   # marker edge width
linestyle='-',            # line style will be dash line
linewidth=2)


ax[1,1].set_xlim(15/R,26/R)
ax[1,1].set_ylim(0,30)



ax[2,0].set_xlabel('MEET (km)',fontsize=18.0, fontweight='bold')
ax[2,1].set_xlabel('MEET (km)',fontsize=18.0, fontweight='bold')

ax[1,0].set_xlim(15/R,26/R)
ax[1,0].set_ylim(0,70)




ax[1,0].set_ylabel('$\Delta$ %MET from $h_{22}$',fontsize=18.0, fontweight='bold',rotation=90)
ax[1,0].yaxis.set_label_coords(-0.12,0.45)

ax[1,1].set_ylabel('$\Delta$ %MET from $k_{22}$',fontsize=18.0, fontweight='bold',rotation=90)
ax[1,1].yaxis.set_label_coords(-0.12,0.45)

ax[0,0].yaxis.set_label_coords(-0.12,0.45)
ax[0,1].yaxis.set_label_coords(-0.12,0.45)



ax[0,0].yaxis.set_major_locator(MultipleLocator(1.5e-2))

ax[0,1].yaxis.set_major_locator(MultipleLocator(0.5e-2))














#####


x=np.array([15/R, 17.5/R, 20/R, 22.5/R, 25/R,27.5/R, 30/R])


X_Y_Spline= make_interp_spline(x,y1s,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)
Y_=X_Y_Spline(X_)



ax[2,1].yaxis.set_label_coords(-0.20,0.5)


#ax[2,1].plot(X_,Y_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



X_Y_Spline2= make_interp_spline(x,y2s,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)
Y2_=X_Y_Spline2(X_)

Y2_spec=Y2_

#ax[2,1].plot(X_,Y2_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)



x1=np.array([15/R, 17.5/R, 20/R,22.5/R, 25/R,27.5/R, 30/R])



X_Y_Spline3= make_interp_spline(x1,y3s,bc_type="natural")
X_ = np.linspace(x.min(),x.max(),500)
Y3_=X_Y_Spline3(X_)

Y3_spec=Y3_
for i in range(len(Y3_)):
    if Y3_[i]<1.0041:
        Y3_[i]=1.004


#ax[2,1].plot(X_,Y3_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)


X_Y_Spline4= make_interp_spline(x1,y4s)
X_ = np.linspace(x.min(),x.max(),500)
Y4_=X_Y_Spline4(X_)

Y4_spec=Y4_

#ax[2,1].plot(X_,Y4_,   
#color='white' ,   # marker edge width
#linestyle='-',            # line style will be dash line
#linewidth=2)




X_Y_Spline5= make_interp_spline(x1,y5s)
X_ = np.linspace(x.min(),x.max(),500)
Y5_=X_Y_Spline5(X_)

Y5_spec=Y5_

ax[2,1].plot(X_,Y5_,   
color='orange' ,   # marker edge width
linestyle='-',            # line style will be dash line
linewidth=2)


#ax[2,1].set_ylim(0.8e-2,2.9e-2)
ax[2,1].set_xlim(15/R,30/R)
#plt.yticks(np.arange(min(Y_), max(Y_), 0.002))
ax[2,1].ticklabel_format(axis="y", style="sci",scilimits=(0,0))

#ax[0].set_xlabel('Mean Elastic Outer Shell Thickness (km)',fontsize=14.0, fontweight='bold')
ax[2,1].set_ylabel('$k_{22}$/$k_{20}$',fontsize=fontsize_label, fontweight='bold',rotation=90)
ax[2,1].yaxis.set_label_coords(-0.12,0.45)






ax[0,0].set_xscale('log')
ax[0,1].set_xscale('log')
ax[1,0].set_xscale('log')
ax[1,1].set_xscale('log')
ax[2,0].set_xscale('log')
ax[2,1].set_xscale('log')

ax[0,0].set_yscale('log')
ax[0,1].set_yscale('log')
ax[1,0].set_xscale('log')
ax[1,1].set_xscale('log')
ax[2,0].set_yscale('log')
ax[2,1].set_yscale('log')

#ax[0,0].xaxis.set_major_locator(MultipleLocator(1.0e-2))
#ax[0,1].xaxis.set_major_locator(MultipleLocator(1.0e-2))

#ax[2,0].xaxis.set_major_locator(MultipleLocator(1.0e-2))
#ax[2,1].xaxis.set_major_locator(MultipleLocator(1.0e-2))





ax[0,0].tick_params(axis='x', which='major', pad=10)
ax[0,1].tick_params(axis='x', which='major', pad=10)
ax[1,0].tick_params(axis='x', which='major', pad=10)
ax[1,1].tick_params(axis='x', which='major', pad=10)
ax[2,0].tick_params(axis='x', which='major', pad=10)
ax[2,1].tick_params(axis='x', which='major', pad=10)



from matplotlib.ticker import FormatStrFormatter


ax[0,0].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax[0,1].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax[1,1].xaxis.set_major_formatter(FormatStrFormatter('%.10g'))
ax[1,0].xaxis.set_major_formatter(FormatStrFormatter('%.10g'))
#
ax[0,0].xaxis.set_major_locator(MultipleLocator(5.0e0))
ax[0,1].xaxis.set_major_locator(MultipleLocator(5.0e0))

ax[2,0].xaxis.set_major_locator(MultipleLocator(5.0e0))
ax[2,1].xaxis.set_major_locator(MultipleLocator(5.0e0))


ax[1,0].set_ylim(0,45)
ax[1,1].set_ylim(0,45)
ax[0,1].set_ylim(1.1e-2,4.7e-2)

ax[2,1].set_ylim(1.0,1.35)

ax[2,0].set_ylim(1.0,1.35)


ax[0,0].axis('off') 
ax[1,0].axis('off') 
ax[0,1].axis('off') 
ax[1,1].axis('off') 
ax[2,0].axis('off') 
ax[2,1].axis('off') 
ax[0,0].axis('off') 
ax[1,0].axis('off') 
ax[0,1].axis('off') 
ax[1,1].axis('off') 
ax[2,0].axis('off') 
ax[2,1].axis('off')




plt.savefig('Response_vs_MST_22.png', dpi=300)
# Out:
# [[0.07737758]
#  [0.06514757]
#  [0.05612256]
#  [0.04912255]
#  [0.04338254]
#  [0.03889004]
#  [0.03493253]]
